# %%
#1. Sourcing and Loading
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load the data
url_LondonHousePrices = 'https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls'
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %%
#2. Cleaning, transforming, and visualizing

# %%
#explore the data
properties.shape
# Out:
# (304, 49)

# %%
#head of data to pre-view df
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
#transpose the df to have Boroughs in rows and dates in columns
properties_T = properties.T

# %%
#check if transpose worked

# %%
properties_T.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
#check if boroughs are indexes or not
properties_T.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
#df index is reset so that borough is not index, for later calculations
properties_T = properties_T.reset_index()

# %%
#check if reset of index worked
properties_T.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
#preview of df to visualize changes performed
properties_T.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# ...

# %%
#check if columns are integers, we want them to be dates
properties_T.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            294,     295,     296,     297,     298,     299,     300,     301,
#            302,     303],
#       dtype='object', length=305)

# %%
#set columns as dates in first row (index 0)
properties_T.columns = properties_T.iloc[0]

# %%
#preview df to see if set of columns worked
properties_T.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
#1st and 2nd rows are duplicated, we eliminate 1st column.
properties_T = properties_T.drop(0)

# %%
#check in df if deletion of 1st row has worked
properties_T.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %%
#rename column Unnamed and NaN
properties_T = properties_T.rename(columns = {'Unnamed: 0':'London_Borough', pd.NaT: 'ID'})
#check in df if changes have worked
properties_T.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# ...

# %%
#check the columns
properties_T.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2019-06-01 00:00:00, 2019-07-01 00:00:00, 2019-08-01 00:00:00,
#        2019-09-01 00:00:00, 2019-10-01 00:00:00, 2019-11-01 00:00:00,
#        2019-12-01 00:00:00, 2020-01-01 00:00:00, 2020-02-01 00:00:00,
#        2020-03-01 00:00:00],
#       dtype='object', name=0, length=305)

# %%
#melt of columns by London_Borough and ID
clean_properties = pd.melt(properties_T, id_vars= ['London_Borough', 'ID'])
#check in df if column melt has worked
clean_properties.head()
# Out:
#        London_Borough         ID          0    value
# 0      City of London  E09000001 1995-01-01    91449
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2              Barnet  E09000003 1995-01-01  93284.5
# 3              Bexley  E09000004 1995-01-01  64958.1
# 4               Brent  E09000005 1995-01-01  71306.6

# %%
#rename columns 0 and value, with Month and Average_price
clean_properties = clean_properties.rename(columns = {0: 'Month', 'value': 'Average_price'})
#check in df if rename has worked
clean_properties.head()
# Out:
#        London_Borough         ID      Month Average_price
# 0      City of London  E09000001 1995-01-01         91449
# 1  Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2              Barnet  E09000003 1995-01-01       93284.5
# 3              Bexley  E09000004 1995-01-01       64958.1
# 4               Brent  E09000005 1995-01-01       71306.6

# %%
#check of data types in df
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %%
#Average_price was an object, we set it to numeric
clean_properties['Average_price'] = pd.to_numeric(clean_properties['Average_price'])
#check if change of dtype has worked in df
clean_properties.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %%
#count the rows with information on all columns
clean_properties.count()
# Out:
# London_Borough    14544
# ID                13635
# Month             14544
# Average_price     13635
# dtype: int64

# %%
#Average_price and ID have less values, check unique values in London_Borough
clean_properties['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
#subset London_Borough == Unnamed: 34 to see what data appears in Average_price, aiming to discard it if no data
clean_properties[clean_properties['London_Borough'] == 'Unnamed: 34'].head()
# Out:
#     London_Borough   ID      Month  Average_price
# 33     Unnamed: 34  NaN 1995-01-01            NaN
# 81     Unnamed: 34  NaN 1995-02-01            NaN
# 129    Unnamed: 34  NaN 1995-03-01            NaN
# 177    Unnamed: 34  NaN 1995-04-01            NaN
# 225    Unnamed: 34  NaN 1995-05-01            NaN

# %%
#subset London_Borough == Unnamed: 37 to see what data appears in Average_price, aiming to discard it if no data
clean_properties[clean_properties['London_Borough'] == 'Unnamed: 37'].head()
# Out:
#     London_Borough   ID      Month  Average_price
# 36     Unnamed: 37  NaN 1995-01-01            NaN
# 84     Unnamed: 37  NaN 1995-02-01            NaN
# 132    Unnamed: 37  NaN 1995-03-01            NaN
# 180    Unnamed: 37  NaN 1995-04-01            NaN
# 228    Unnamed: 37  NaN 1995-05-01            NaN

# %%
#Ask Dr. Maskall for alternative way to do this deletion
# Create variable for each London_Borough == Unnamed:34 and Unnamed: 37 to get the index and later on use index to drop()
delete_34 = clean_properties[ clean_properties['London_Borough'] == 'Unnamed: 34' ].index
delete_37 = clean_properties[ clean_properties['London_Borough'] == 'Unnamed: 37' ].index

# %%
#Use of drop() on the variables created to delete them form df
clean_properties.drop(delete_34 , inplace=True)
clean_properties.drop(delete_37 , inplace=True)

# %%
#Subset df based on if ID has NaN, aiming to discard them
clean_properties[clean_properties['ID'].isna()]
# Out:
#       London_Borough   ID      Month  Average_price
# 46       Unnamed: 47  NaN 1995-01-01            NaN
# 94       Unnamed: 47  NaN 1995-02-01            NaN
# 142      Unnamed: 47  NaN 1995-03-01            NaN
# 190      Unnamed: 47  NaN 1995-04-01            NaN
# 238      Unnamed: 47  NaN 1995-05-01            NaN
# ...              ...  ...        ...            ...
# 14350    Unnamed: 47  NaN 2019-11-01            NaN
# 14398    Unnamed: 47  NaN 2019-12-01            NaN
# 14446    Unnamed: 47  NaN 2020-01-01            NaN
# 14494    Unnamed: 47  NaN 2020-02-01            NaN
# 14542    Unnamed: 47  NaN 2020-03-01            NaN
#
# [303 rows x 4 columns]

# %%
#Create variable, assign subset of df with condition that Average_price is not NaN
NaNFreeDF1 = clean_properties[clean_properties['Average_price'].notna()]
#Check if it has worked
NaNFreeDF1.head(48)
# Out:
#           London_Borough         ID      Month  Average_price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# ...

# %%
#After deletion of NANs on ID to check if all columns have data
NaNFreeDF1.count()
# Out:
# London_Borough    13635
# ID                13635
# Month             13635
# Average_price     13635
# dtype: int64

# %%
#second way to filter, create variable and assign subset based on condition dropna(), delete if NaN
NaNFreeDF2 = clean_properties.dropna()
#Check if deletion has worked
NaNFreeDF2.head(48)
# Out:
#           London_Borough         ID      Month  Average_price
# 0         City of London  E09000001 1995-01-01    91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                 Barnet  E09000003 1995-01-01    93284.51832
# 3                 Bexley  E09000004 1995-01-01    64958.09036
# 4                  Brent  E09000005 1995-01-01    71306.56698
# 5                Bromley  E09000006 1995-01-01    81671.47692
# 6                 Camden  E09000007 1995-01-01   120932.88810
# 7                Croydon  E09000008 1995-01-01    69158.16225
# 8                 Ealing  E09000009 1995-01-01    79885.89069
# 9                Enfield  E09000010 1995-01-01    72514.69096
# 10             Greenwich  E09000011 1995-01-01    62300.10169
# 11               Hackney  E09000012 1995-01-01    61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01   124902.86020
# 13              Haringey  E09000014 1995-01-01    76287.56947
# ...

# %%
#count values on rows on new variable to check if all columns have data
NaNFreeDF2.count()
# Out:
# London_Borough    13635
# ID                13635
# Month             13635
# Average_price     13635
# dtype: int64

# %%
#check unique values on London_Borough to further filter non Boroughs (in capital letters)
NaNFreeDF2['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
#Exploration of data on the new created variables, following different cleaning procedures
print(clean_properties.shape)
# using first procedure .notna() as part of subset on df
print(NaNFreeDF1.shape)
#using second procedure .dropna() as method on df
print(NaNFreeDF2.shape)
# Out:
# (13938, 4)
# (13635, 4)
# (13635, 4)

# %%
#create a list of Boroughs that we want to delete in next step, this list will be used as condition to subset
nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
# create a variable and assign a subset based on negative condition, if NOT London_Borough is in previous list nonBoroughs
df = NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]

# %%
#check unique values on new df to see if the deletion worked
df['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster'], dtype=object)

# %%
#preview of new df 
df.head()
# Out:
#        London_Borough         ID      Month  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
#check the data types of new df
df.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %%
#2.6. Visualizing the data
#Create a variable and assign to it a subset of df based on the condition that London_Borough is Camden
camden_prices = df[df['London_Borough'] == 'Camden']

# %%
#create a variable and assign to it the plot of previous variable, with arguments, kind line, x month and y average price
ax = camden_prices.plot(kind ='line', x = 'Month', y='Average_price')

# %%
#set the y label in the plot to price
ax.set_ylabel('Price')
# Out:
# Text(3.200000000000003, 0.5, 'Price')

# %%
#Create a new column year with a lambda function that gets the year from the date on Month column
#Ask Dr. Maskall about this error
df['Year'] = df['Month'].apply(lambda t: t.year)
# Out:
# C:\Users\34658\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#using groupby method on df to aggregate by Borough and Year and get the mean from them
dfg = df.groupby(by=['London_Borough', 'Year']).mean()
#get a sample of 10 observations
dfg.sample(10)
# Out:
#                            Average_price
# London_Borough       Year
# Tower Hamlets        2014  382241.688900
# Redbridge            2016  391837.313350
#                      2007  266937.789575
# Lewisham             1997   66150.695685
# Lambeth              2002  190451.027867
# Hackney              2003  201071.484342
# Kingston upon Thames 2013  345739.148542
# Waltham Forest       2013  254265.265442
# Havering             2006  211316.593400
# Harrow               1996   85926.701202

# %%
#rest index of df because we can't make calculations with indexes
dfg = dfg.reset_index()
#check if it has worked
dfg.head()
# Out:
#        London_Borough  Year  Average_price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %%
#3. Modeling
#create a function that divides one variable between another
#first variable is year 1998 avg prices - we calculate it as average price from d with condition year 1998
#first variable is year 2018 avg prices - we calculate it as average price from d with condition year 2018
def create_price_ratio(d):
    y1998 = float(d['Average_price'][d['Year']==1998])
    y2018 = float(d['Average_price'][d['Year']==2018])
    ratio = [y2018/y1998]
    return ratio

# %%
#test of the function with one Borough to see if it works
create_price_ratio(dfg[dfg['London_Borough']=='Barking & Dagenham'])
# Out:
# [4.89661861291754]

# %%
#to apply this function to all Boroughs we will need to store results of function somewhere, we create an empty dictionary for this purpose.
final = {}

# %%
#we make a loop that goes on unique Boroughs and makes the following
for b in dfg['London_Borough'].unique():
    #create a variable that stores the value of the key
    borough = dfg[dfg['London_Borough'] == b]
    #makes an entry in hte ditionary  with this key, key = unique Borough, value = function applied to that key
    final[b] = create_price_ratio(borough)
# we check if it worked by printing the dictionary, that now is populated with data
print(final)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.0947846853338765], 'Camden': [4.935353408884261], 'City of London': [5.301620377587609], 'Croydon': [4.201100280024767], 'Ealing': [4.311450902121834], 'Enfield': [4.26347158349581], 'Greenwich': [4.763036347329193], 'Hackney': [6.198285561008662], 'Hammersmith & Fulham': [4.137798101936229], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335308], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Islington': [4.844048012802298], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'Lambeth': [4.957751163514063], 'Lewisham': [5.449221041059685], 'Merton': [4.741273313294604], 'Newham': [5.305390437201879], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'Southwark': [5.516485302379376], 'Sutton': [4.1185226085
# ...

# %%
#we make a new variable to store the dictionary, but in data frame type
df_ratios = pd.DataFrame(final)

# %%
#preview the new variable
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
#as before, we need to transpose and reindex the dataframe to be able to use the Boroughs
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
#check if the transformations worked
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
# Let's just rename the 'index' column as 'London_Borough', and the '0' column to '2018'.
df_ratios.rename(columns={'index':'Borough', 0:'2018'}, inplace=True)
df_ratios.head()
# Out:
#               Borough      2018
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
#as example, we create a variable and assign it to a sorted df, by year, in descending order and show the first 15 results
top15 = df_ratios.sort_values(by='2018',ascending=False).head(15)
print(top15)
# Out:
#                  Borough      2018
# 11               Hackney  6.198286
# 30        Waltham Forest  5.834756
# 27             Southwark  5.516485
# 22              Lewisham  5.449221
# 32           Westminster  5.353565
# 24                Newham  5.305390
# 6         City of London  5.301620
# 13              Haringey  5.134625
# 19  Kensington & Chelsea  5.082465
# 21               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 18             Islington  4.844048
# 10             Greenwich  4.763036

# %%
#to plot this, we create a variable and assing to it the subset of Borough and 2018 columns, as histogram.
af = top15[['Borough','2018']].plot(kind='bar')
#we define the xtick labels based on Borough column values
af.set_xticklabels(top15.Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(0, 0, 'Waltham Forest'),
#  Text(0, 0, 'Southwark'),
#  Text(0, 0, 'Lewisham'),
#  Text(0, 0, 'Westminster'),
#  Text(0, 0, 'Newham'),
#  Text(0, 0, 'City of London'),
#  Text(0, 0, 'Haringey'),
#  Text(0, 0, 'Kensington & Chelsea'),
#  Text(0, 0, 'Lambeth'),
#  Text(0, 0, 'Camden'),
#  Text(0, 0, 'Barking & Dagenham'),
#  Text(0, 0, 'Brent'),
#  Text(0, 0, 'Islington'),
#  Text(0, 0, 'Greenwich')]

# %%
# create the df of the bottom 15 and visualize them
bottom15 = df_ratios.sort_values(by='2018',ascending=False).tail(15)
print(bottom15)
#to plot this, we create a variable and assing to it the subset of Borough and 2018 columns, as histogram.
af2 = bottom15[['Borough','2018']].plot(kind='bar')
#we define the xtick labels based on Borough column values
af2.set_xticklabels(bottom15.Borough)
# Out:
#                  Borough      2018
# 25             Redbridge  4.471182
# 1                 Barnet  4.358196
# 15              Havering  4.325230
# 8                 Ealing  4.311451
# 20  Kingston upon Thames  4.270550
# 9                Enfield  4.263472
# 2                 Bexley  4.248977
# 7                Croydon  4.201100
# 16            Hillingdon  4.200273
# 12  Hammersmith & Fulham  4.137798
# 28                Sutton  4.118523
# 4                Bromley  4.094785
# 14                Harrow  4.059196
# 26  Richmond upon Thames  4.005162
# 17              Hounslow  3.976409
# [Text(0, 0, 'Redbridge'),
#  Text(0, 0, 'Barnet'),
#  Text(0, 0, 'Havering'),
#  Text(0, 0, 'Ealing'),
#  Text(0, 0, 'Kingston upon Thames'),
#  Text(0, 0, 'Enfield'),
#  Text(0, 0, 'Bexley'),
#  Text(0, 0, 'Croydon'),
#  Text(0, 0, 'Hillingdon'),
#  Text(0, 0, 'Hammersmith & Fulham'),
#  Text(0, 0, 'Sutton'),
#  Text(0, 0, 'Bromley'),
#  Text(0, 0, 'Harrow'),
#  Text(0, 0, 'Richmond upon Thames'),
# ...

# %%
#ADVANCED MODEL - Second upload to Github with more data
#Get the statistics of the df
df_ratios['2018'].describe()
# Out:
# count    33.000000
# mean      4.716235
# std       0.571489
# min       3.976409
# 25%       4.248977
# 50%       4.741273
# 75%       5.082465
# max       6.198286
# Name: 2018, dtype: float64

# %%
#Visualize the distribution
ax2 = df_ratios.hist(bins = 15, alpha = 0.5)
plt.xlabel('Ratio of Price Growth (1998-2018)')
plt.ylabel('Nº of Boroughs')
# Out:
# Text(0, 0.5, 'Nº of Boroughs')

# %%
#plot price evolution, does not give a clear vision per Borough, but there is an upward trend of prices
plt.plot(dfg['Year'],dfg['Average_price'])
plt.xlabel('Years')
plt.ylabel('Housing Prices')
# Out:
# Text(0, 0.5, 'Housing Prices')

# %%
#Create a new variable with the mean data per year to plot it and see trend
mean_year = dfg.groupby('Year').mean()
plt.plot(mean_year)
plt.xlabel('Years')
plt.ylabel('Average Price of Houses')
# Out:
# Text(0, 0.5, 'Average Price of Houses')
